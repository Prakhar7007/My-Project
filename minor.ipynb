# %%
import pandas as pd 
import matplotlib as plt
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
count=["confirmed","recovered","active","death"]
numbers=[31156,20331,9980,845]
plt.plot(count,numbers)
plt.title("status of up")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()

# %%
import matplotlib.pyplot as plt
count=["confirmed","recoverd","active","deaths"]
numbers=[13189,9554,3528,107]
plt.plot(count,numbers)
plt.title("status_of_bihar_COVID19")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

x2=["confirmed","recovered","active","death"]
y2=[13189,9554,3528,107]
x=["confirmed","recovered","active","death"]
y=[31156,20331,9980,845]
plt.plot(x,y,'g',label='uttar pradesh',linewidth=5)
plt.plot(x2,y2,'c',label='bihar',linewidth=5)
plt.plot(count,numbers)
plt.title("status of uttar pradesh and bihar COVID19")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.grid(True,color='k')
plt.legend()
plt.show()
