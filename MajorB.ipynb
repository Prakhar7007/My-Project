# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("covid_19_india1.csv")

# %%
data.drop('ConfirmedIndianNational',axis=1,inplace=True)
data
# Out:
#      Sno      Date     Time State/UnionTerritory     Cured    Deaths  \
# 0      1  30/01/20  6:00 PM               Kerala  0.000000  0.000000
# 1      2  31/01/20  6:00 PM               Kerala  0.000000  0.000000
# 2      3  1/2/2020  6:00 PM               Kerala  0.000000  0.000000
# 3      4  2/2/2020  6:00 PM               Kerala  0.000000  0.000000
# 4      5  3/2/2020  6:00 PM               Kerala  0.000000  0.000000
# ..   ...       ...      ...                  ...       ...       ...
# 652  653  7/3/2020  6:00 PM           Tamil Nadu  5.171296  1.545155
# 653  654  7/3/2020  6:00 PM                Delhi  5.180413  1.548040
# 654  655  7/3/2020  6:00 PM              Haryana  5.189531  1.550925
# 655  656  7/3/2020  6:00 PM            Rajasthan  5.198649  1.553809
# 656  657  8/3/2020  6:00 PM               Ladakh  5.207766  1.556694
#
#      Confirmed  Active
# 0     1.000000  291476
# 1     1.000000   99202
# 2     2.000000   46413
# 3     3.000000   19895
# ...

# %%
state = pd.DataFrame(data[data["State/UnionTerritory"]=="Ladakh"])

state
# Out:
#      Sno       Date     Time State/UnionTerritory      Cured    Deaths  \
# 59    60   7/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 65    66   8/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 73    74   9/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 86    87  10/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 104  105  11/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 115  116  12/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 196  197   7/3/2020  6:00 PM               Ladakh   3.000000  0.000000
# 256  257   7/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 262  263   8/3/2020  6:00 PM               Ladakh   1.000000  0.000000
# 270  271   9/3/2020  6:00 PM               Ladakh   0.000000  0.000000
# 283  284  10/3/2020  6:00 PM               Ladakh   0.000000  1.000000
# 301  302  11/3/2020  6:00 PM               Ladakh   3.000000  0.000000
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(state.corr(),annot=True,linewidth=1,linecolor="blue")
